# %%
nik = "617************1"
nama = "Steven Susanto"
jk = "Laki-Laki"
ttl = "Pontianak, 21-04-2002"
gol_drh = "-"
alamat = "Gang Bangau"
rt_rw = "005/005"
kel_desa = "Mariana"
kecamatan = "Pontianak Kota"
agama = "Katolik"
menikah = False
pekerjaan = "Belum/Tidak Bekerja"
kewarganegaraan = "WNI"
berlaku = "Seumur Hidup"

#cetak
print("====================================================")
print("===========KTP PROVINSI KALIMANTAN BARAT============")
print("===================KOTA PONTIANAK===================")
print("====================================================")
print("NIK               : ", nik)
print("Nama              : ", nama)
print("Jenis Kelamin     : ", jk)
print("Tempat/Tgl Lahir  : ", ttl)
print("Golongan Darah    : ", gol_drh)
print("Alamat            : ", alamat)
print("    RT/RW         : ", rt_rw)
print("    Kel/Desa      : ", kel_desa)
print("    Kecamatan     : ", kecamatan)
print("Agama             : ", agama)
if(menikah) :
    print("Status Perkawinan :  Kawin")
else: 
    print("Status Perkawinan :  Belum Kawin")
print("Pekerjaan         : ", pekerjaan)
print("Kewarganegaraan   : ", kewarganegaraan)
print("Berlaku Hingga    : ", berlaku)
print("====================================================")
print("====================================================")
print("====================================================")
print("====================================================")
# Out:
# ====================================================
# ===========KTP PROVINSI KALIMANTAN BARAT============
# ===================KOTA PONTIANAK===================
# ====================================================
# NIK               :  617************1
# Nama              :  Steven Susanto
# Jenis Kelamin     :  Laki-Laki
# Tempat/Tgl Lahir  :  Pontianak, 21-04-2002
# Golongan Darah    :  -
# Alamat            :  Gang Bangau
#     RT/RW         :  005/005
#     Kel/Desa      :  Mariana
#     Kecamatan     :  Pontianak Kota
# Agama             :  Katolik
# Status Perkawinan :  Belum Kawin
# Pekerjaan         :  Belum/Tidak Bekerja
# Kewarganegaraan   :  WNI
# Berlaku Hingga    :  Seumur Hidup
# ====================================================
# ====================================================
# ====================================================
# ====================================================

# %%
sim = """
    INDONESIA
    SURAT IZIN MENGEMUDI
    """
dl_c = """
                             DRIVING LICENSE
                                    C
                            "10**-****-****38"
                            """
nama = "Steven Susanto"
ttl = "Pontianak, 21-04-2002"
jk = "--Pria"
alamat = "Gg Bangau"
kel_desa = "Mariana"
kec = "Pontianak Kota"
pekerjaan = "Pelajar"
prov = "Kalbar"
footer = """
=================================================
"""

#cetak
print("=================================================")
print("", sim)
print("", dl_c)
print("")
print("1.", nama)
print("2.", ttl)
print("3.", jk)
print("4.", alamat)
print("  " , kel_desa)
print("  " , kec)
print("5.", pekerjaan)
print("6.", prov)
print("", footer)
# Out:
# =================================================
#
#     INDONESIA
#     SURAT IZIN MENGEMUDI
#
#
#                              DRIVING LICENSE
#                                     C
#                             "10**-****-****38"
#
#
# 1. Steven Susanto
# 2. Pontianak, 21-04-2002
# 3. --Pria
# 4. Gg Bangau
#    Mariana
#    Pontianak Kota
# 5. Pelajar
# 6. Kalbar
#
# =================================================

# %%
data_pr = """
Data Pribadi
"""
nama = "Steven Susanto"
ttl = "Pontianak, 21-04-2002"
jk = "Laki-Laki"
agama = "Katolik"
tb = "170 cm"
bb = "61 Kg"
alamat = "Gang Bangau"
rt_rw = "005/005"
kel_desa = "Mariana"
kecamatan = "Pontianak Kota"
hp = "089521366928"
menikah = False
e_mail = "steven8******3@gmail.com"

data_pe = """
Data Pendidikan
"""
formal = """
   Pendidikan Formal
"""
sd = "SD Suster Pontianak"
smp = "SMP Bruder Pontianak"
sma = "SMA Santo Paulus Pontianak"
pt = "STMIK Pontianak"

non_f = """
   Pendidikan Non-Formal
"""
k_english = "1. Universal English Course"
b_ganesha = "2. Ganesha Operation"

ekskul = """
Ekstra Kurikuler
"""
ksp = "1. Koor SMA Santo Paulus"
band = "2. Band SMA Santo Paulus"

pengker = """
Pengalaman Kerja
"""
sales = "1. Sales Toko Baju"
cashier = "2. Cashier Toko Baju"

prestasi = """
Penghargaan
"""
p_cup = "1. Runner Up Basketball Competition Petrus Cup IV 2013"
fr_1 = "2. Juara 1 Fashion Road Pontianak Oktober Festival 2017"
fr_2 = "3. Juara 1 Fashion Road HUT Kota Pontianak ke-247 2018"

footer="""
=============================================================
=============================================================
=============================================================
        """
#cetak
print("=============================================================")
print("======================CURRICULUM VITAE=======================")
print("=============================================================")
print("", data_pr)
print("   Nama              : ", nama)
print("   Tempat/Tgl Lahir  : ", ttl)
print("   Jenis Kelamin     : ", jk)
print("   Agama             : ", agama)
print("   Tinggi Badan      : ", tb)
print("   Berat Badan       : ", bb)
print("   Alamat            : ", alamat)
print("       RT/RW         : ", rt_rw)
print("       Kel/Desa      : ", kel_desa)
print("       Kecamatan     : ", kecamatan)
print("   Handphone         : ", hp)
if(menikah) :
    print("   Status Perkawinan :  Kawin")
else: 
    print("   Status Perkawinan :  Belum Kawin")
print("   E-mail            : ", e_mail)

print("", data_pe)
print("", formal)
print("   SD                : ", sd)
print("   SMP               : ", smp)
print("   SMA               : ", sma)
print("   Perguruan Tinggi  : ", pt)
print("", non_f)
print("  ", k_english)
print("  ", b_ganesha)

print("", ekskul)
print("  ", ksp)
print("  ", band)

print("", pengker)
print("  ", sales)
print("  ", cashier)

print("", prestasi)
print("  ", p_cup)
print("  ", fr_1)
print("  ", fr_2)

print("", footer)
# Out:
# =============================================================
# ======================CURRICULUM VITAE=======================
# =============================================================
#
# Data Pribadi
#
#    Nama              :  Steven Susanto
#    Tempat/Tgl Lahir  :  Pontianak, 21-04-2002
#    Jenis Kelamin     :  Laki-Laki
#    Agama             :  Katolik
#    Tinggi Badan      :  170 cm
#    Berat Badan       :  61 Kg
#    Alamat            :  Gang Bangau
#        RT/RW         :  005/005
#        Kel/Desa      :  Mariana
#        Kecamatan     :  Pontianak Kota
#    Handphone         :  089521366928
#    Status Perkawinan :  Belum Kawin
#    E-mail            :  steven8******3@gmail.com
#
# Data Pendidikan
#
#
#    Pendidikan Formal
#
#    SD                :  SD Suster Pontianak
#    SMP               :  SMP Bruder Pontianak
#    SMA               :  SMA Santo Paulus Pontianak
#    Perguruan Tinggi  :  STMIK Pontianak
#
#    Pendidikan Non-Formal
#
#    1. Universal English Course
#    2. Ganesha Operation
#
# Ekstra Kurikuler
#
#    1. Koor SMA Santo Paulus
#    2. Band SMA Santo Paulus
#
# Pengalaman Kerja
#
#    1. Sales Toko Baju
#    2. Cashier Toko Baju
#
# Penghargaan
#
#    1. Runner Up Basketball Competition Petrus Cup IV 2013
#    2. Juara 1 Fashion Road Pontianak Oktober Festival 2017
#    3. Juara 1 Fashion Road HUT Kota Pontianak ke-247 2018
#
# =============================================================
# =============================================================
# =============================================================
